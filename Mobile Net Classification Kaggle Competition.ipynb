# %% [markdown]
# # 1. Importing packages

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import random
import os

from tensorflow.keras.layers import Input , Dense , Flatten , GlobalAveragePooling2D
from tensorflow.keras.models import Sequential

# %%
path = '../input/4-animal-classification'

# %% [markdown]
# # 2. Visualising data

# %%
names = []
nums = []
data = {'Name of class':[],'Number of samples':[]}

for i in os.listdir(path+'/train'):
    nums.append(len(os.listdir(path+'/train/'+i)))
    names.append(i)

data['Name of class']+=names
data['Number of samples']+=nums

df = pd.DataFrame(data)
df
# Out:
#   Name of class  Number of samples
# 0         horse                600
# 1           dog                900
# 2           cat                700
# 3          deer                600

# %%
sns.barplot(x=df['Name of class'],y=df['Number of samples'])
# Out:
# <AxesSubplot:xlabel='Name of class', ylabel='Number of samples'>

# %%
classes = os.listdir(path+'/train')

plt.figure(figsize=(30 , 30))
for x in range(10):
    i = random.randint(0,3)                    # getting the class
    images = os.listdir(path+'/train'+'/'+classes[i])
    j = random.randint(0,600)                  # getting the image
    image = cv2.imread(path+'/train'+'/'+classes[i]+'/'+images[j])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    ax = plt.subplot(5, 5, x + 1)
    plt.imshow(image)
    plt.title(classes[i])
    plt.axis("off")

plt.show()

# %% [markdown]
# # 3. Preparing the data

# %%
image_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255 , rotation_range=20,
                                                                width_shift_range=0.2,
                                                                height_shift_range=0.2,
                                                                horizontal_flip=True, validation_split=0.2)

# %%
train_ds = image_datagen.flow_from_directory(
        path+'/train',
        subset='training',
        target_size=(224 , 224),
        batch_size=64)

val_ds = image_datagen.flow_from_directory(
        path+'/train',
        subset='validation',
        target_size=(224 , 224),
        batch_size=64)
# Out:
# Found 2240 images belonging to 4 classes.
# Found 560 images belonging to 4 classes.

# %% [markdown]
# # 4. Building the model

# %%
# i'll be using inception_v3 for this model , along with 2 extra dense layers and the output layer

mobilenet = tf.keras.applications.mobilenet.MobileNet(input_shape=(224 , 224, 3),
                                           include_top=False,
                                           weights='imagenet')

model = Sequential()
model.add(mobilenet)
model.add(GlobalAveragePooling2D())
model.add(Flatten())
model.add(Dense(1024, activation="relu"))
model.add(Dense(1024, activation="relu"))
model.add(Dense(4, activation="softmax" , name="classification"))
# Out:
# 2022-09-26 07:27:36.435361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:36.528166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:36.528994: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:36.530617: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-26 07:27:36.530906: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:36.531571: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:36.532235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:38.669290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:38.670237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:38.670928: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 07:27:38.671696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0010,momentum=0.9), 
            loss='categorical_crossentropy',
            metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# classification (Dense)       (None, 4)                 4100
# =================================================================
# Total params: 5,332,164
# Trainable params: 5,310,276
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# # 5. Training and evaluating

# %%
history = model.fit(train_ds , validation_data = val_ds , epochs = 100)
# Out:
# 2022-09-26 07:27:57.307803: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-09-26 07:28:02.205048: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 35/35 [==============================] - 74s 2s/step - loss: 0.9825 - accuracy: 0.6214 - val_loss: 0.5552 - val_accuracy: 0.8286
# Epoch 2/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.3536 - accuracy: 0.8991 - val_loss: 0.3068 - val_accuracy: 0.9196
# Epoch 3/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.2284 - accuracy: 0.9353 - val_loss: 0.2425 - val_accuracy: 0.9250
# Epoch 4/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.1526 - accuracy: 0.9554 - val_loss: 0.1907 - val_accuracy: 0.9393
# Epoch 5/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.1268 - accuracy: 0.9603 - val_loss: 0.1627 - val_accuracy: 0.9571
# Epoch 6/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.1105 - accuracy: 0.9674 - val_loss: 0.1614 - val_accuracy: 0.9536
# Epoch 7/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0905 - accuracy: 0.9750 - val_loss: 0.1475 - val_accuracy: 0.9554
# Epoch 8/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0813 - accuracy: 0.9781 - val_loss: 0.1496 - val_accuracy: 0.9589
# Epoch 9/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0817 - accuracy: 0.9746 - val_loss: 0.1440 - val_accuracy: 0.9482
# Epoch 10/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0638 - accuracy: 0.9808 - val_loss: 0.1257 - val_accuracy: 0.9571
# Epoch 11/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0575 - accuracy: 0.9844 - val_loss: 0.1372 - val_accuracy: 0.9554
# Epoch 12/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0530 - accuracy: 0.9862 - val_loss: 0.1249 - val_accuracy: 0.9571
# Epoch 13/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0438 - accuracy: 0.9884 - val_loss: 0.1256 - val_accuracy: 0.9589
# Epoch 14/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0397 - accuracy: 0.9897 - val_loss: 0.1184 - val_accuracy: 0.9589
# Epoch 15/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.0402 - accuracy: 0.9888 - val_loss: 0.1157 - val_accuracy: 0.9589
# Epoch 16/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0363 - accuracy: 0.9915 - val_loss: 0.1307 - val_accuracy: 0.9482
# Epoch 17/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0284 - accuracy: 0.9946 - val_loss: 0.1349 - val_accuracy: 0.9500
# Epoch 18/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0282 - accuracy: 0.9946 - val_loss: 0.1229 - val_accuracy: 0.9554
# Epoch 19/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0264 - accuracy: 0.9933 - val_loss: 0.1267 - val_accuracy: 0.9518
# Epoch 20/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.0246 - accuracy: 0.9942 - val_loss: 0.1372 - val_accuracy: 0.9589
# Epoch 21/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0233 - accuracy: 0.9946 - val_loss: 0.1230 - val_accuracy: 0.9536
# Epoch 22/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.1222 - val_accuracy: 0.9536
# Epoch 23/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.1474 - val_accuracy: 0.9464
# Epoch 24/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0195 - accuracy: 0.9973 - val_loss: 0.1271 - val_accuracy: 0.9625
# Epoch 25/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0170 - accuracy: 0.9982 - val_loss: 0.1187 - val_accuracy: 0.9554
# Epoch 26/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0162 - accuracy: 0.9978 - val_loss: 0.1350 - val_accuracy: 0.9518
# Epoch 27/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0172 - accuracy: 0.9960 - val_loss: 0.1188 - val_accuracy: 0.9607
# Epoch 28/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0162 - accuracy: 0.9969 - val_loss: 0.1180 - val_accuracy: 0.9607
# Epoch 29/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0120 - accuracy: 0.9978 - val_loss: 0.1236 - val_accuracy: 0.9571
# Epoch 30/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0124 - accuracy: 0.9978 - val_loss: 0.1342 - val_accuracy: 0.9589
# Epoch 31/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0114 - accuracy: 0.9996 - val_loss: 0.1369 - val_accuracy: 0.9607
# Epoch 32/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0126 - accuracy: 0.9987 - val_loss: 0.1152 - val_accuracy: 0.9643
# Epoch 33/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0144 - accuracy: 0.9964 - val_loss: 0.1160 - val_accuracy: 0.9661
# Epoch 34/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0102 - accuracy: 0.9987 - val_loss: 0.1077 - val_accuracy: 0.9625
# Epoch 35/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0102 - accuracy: 0.9987 - val_loss: 0.1286 - val_accuracy: 0.9661
# Epoch 36/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.1258 - val_accuracy: 0.9643
# Epoch 37/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0115 - accuracy: 0.9973 - val_loss: 0.1354 - val_accuracy: 0.9607
# Epoch 38/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0103 - accuracy: 0.9982 - val_loss: 0.1402 - val_accuracy: 0.9554
# Epoch 39/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0096 - accuracy: 0.9982 - val_loss: 0.1110 - val_accuracy: 0.9661
# Epoch 40/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0993 - val_accuracy: 0.9714
# Epoch 41/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0080 - accuracy: 0.9987 - val_loss: 0.1234 - val_accuracy: 0.9589
# Epoch 42/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 0.1176 - val_accuracy: 0.9661
# Epoch 43/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.1170 - val_accuracy: 0.9679
# Epoch 44/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.1315 - val_accuracy: 0.9554
# Epoch 45/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0064 - accuracy: 0.9996 - val_loss: 0.1369 - val_accuracy: 0.9589
# Epoch 46/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9607
# Epoch 47/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.1346 - val_accuracy: 0.9554
# Epoch 48/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 0.1095 - val_accuracy: 0.9589
# Epoch 49/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9643
# Epoch 50/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.1337 - val_accuracy: 0.9571
# Epoch 51/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.1175 - val_accuracy: 0.9625
# Epoch 52/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.1267 - val_accuracy: 0.9589
# Epoch 53/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.1300 - val_accuracy: 0.9661
# Epoch 54/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9661
# Epoch 55/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0056 - accuracy: 0.9991 - val_loss: 0.1209 - val_accuracy: 0.9625
# Epoch 56/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 0.1264 - val_accuracy: 0.9607
# Epoch 57/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.1369 - val_accuracy: 0.9571
# Epoch 58/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9643
# Epoch 59/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.1347 - val_accuracy: 0.9643
# Epoch 60/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.1286 - val_accuracy: 0.9643
# Epoch 61/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.1180 - val_accuracy: 0.9571
# Epoch 62/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0052 - accuracy: 0.9996 - val_loss: 0.1102 - val_accuracy: 0.9679
# Epoch 63/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0043 - accuracy: 0.9996 - val_loss: 0.1411 - val_accuracy: 0.9554
# Epoch 64/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1171 - val_accuracy: 0.9607
# Epoch 65/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.1114 - val_accuracy: 0.9625
# Epoch 66/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.0045 - accuracy: 0.9996 - val_loss: 0.1074 - val_accuracy: 0.9661
# Epoch 67/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.1609 - val_accuracy: 0.9571
# Epoch 68/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9696
# Epoch 69/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.1220 - val_accuracy: 0.9661
# Epoch 70/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.1147 - val_accuracy: 0.9661
# Epoch 71/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1375 - val_accuracy: 0.9625
# Epoch 72/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.1556 - val_accuracy: 0.9554
# Epoch 73/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0052 - accuracy: 0.9978 - val_loss: 0.1577 - val_accuracy: 0.9589
# Epoch 74/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9661
# Epoch 75/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.1193 - val_accuracy: 0.9696
# Epoch 76/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9679
# Epoch 77/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0041 - accuracy: 0.9996 - val_loss: 0.1654 - val_accuracy: 0.9625
# Epoch 78/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9607
# Epoch 79/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.1388 - val_accuracy: 0.9554
# Epoch 80/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.1386 - val_accuracy: 0.9643
# Epoch 81/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.1322 - val_accuracy: 0.9643
# Epoch 82/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1515 - val_accuracy: 0.9661
# Epoch 83/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9571
# Epoch 84/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.1432 - val_accuracy: 0.9589
# Epoch 85/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9625
# Epoch 86/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.1156 - val_accuracy: 0.9696
# Epoch 87/100
# 35/35 [==============================] - 49s 1s/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1401 - val_accuracy: 0.9607
# Epoch 88/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.1565 - val_accuracy: 0.9607
# Epoch 89/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.1558 - val_accuracy: 0.9571
# Epoch 90/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1589 - val_accuracy: 0.9500
# Epoch 91/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.1423 - val_accuracy: 0.9625
# Epoch 92/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.1770 - val_accuracy: 0.9589
# Epoch 93/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.1310 - val_accuracy: 0.9607
# Epoch 94/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.1309 - val_accuracy: 0.9696
# Epoch 95/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.1368 - val_accuracy: 0.9643
# Epoch 96/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9625
# Epoch 97/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9571
# Epoch 98/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9625
# Epoch 99/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9625
# Epoch 100/100
# 35/35 [==============================] - 50s 1s/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.1548 - val_accuracy: 0.9625

# %%
model.evaluate(val_ds)

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'],loc='upper right')
plt.show()
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy','val_accuracy'],loc='upper right')
plt.show()
# Out:
# 9/9 [==============================] - 10s 1s/step - loss: 0.1530 - accuracy: 0.9571

# %% [markdown]
# # 6. Preparing for submission

# %%
sub_csv ='../input/4-animal-classification/Sample_submission.csv'
path_test = '../input/4-animal-classification/test/test'

# %%
df_sub = pd.read_csv(sub_csv)
image_id = df_sub['ID']
df_sub.head(10)
# Out:
#    ID  Label
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
# 5   6      0
# 6   7      0
# 7   8      0
# 8   9      0
# 9  10      0

# %%
# each image will be treated individually and saved in a list which is then merged with the id of it's correspondence

from tensorflow.keras.preprocessing.image import load_img


# making a list for our predictions
labels = []


for i in image_id:
    image = load_img(path_test+'/'+str(i)+'.jpg', target_size=(224, 224))
    img = np.array(image)
    img = img / 255.0
    img = img.reshape(1,224,224,3)
    label = model.predict(img)
    label_id = label[0].tolist()
    
    labels.append(label_id.index(max(label_id)))

# %%
# we will replace the previous empty columns with the new predictions    
    
df_sub['Label'] = labels
df_sub.head(10)
# Out:
#    ID  Label
# 0   1      1
# 1   2      0
# 2   3      2
# 3   4      3
# 4   5      2
# 5   6      1
# 6   7      3
# 7   8      0
# 8   9      3
# 9  10      2

# %%
# saving file
df_sub.to_csv('submission_file.csv',index=False)
